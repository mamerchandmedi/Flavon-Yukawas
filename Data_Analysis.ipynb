# %%
import numpy as np
from cosmoTransitions import generic_potential_1
import matplotlib.pyplot as plt
import pandas as pd
from scipy import optimize
import scipy.integrate as integrate
from scipy import interpolate


####Some definitions##
v2 = 246.**2 
mh=125
v=246
alpha=1/137 #fine structure constant
sinthw=np.sqrt(0.223) #sine of Weinberg angle
g1=np.sqrt(4*np.pi*alpha/(1-sinthw**2)) ## U(1)_Y gauge coupling constant
g=np.sqrt(4*np.pi*alpha)/sinthw #SU(2)_L gauge coupling constant
Mplanck=2.4*10**18 #reduced planck mass
cs=1/3**0.5 ##Sound speed constant

###Experimental data for fermion masses and mixing angles, taken from past project
mu=2.3*10**(-3)
deltamu=0.6*10**(-3)
mc=1.275
deltamc=0.025
mt=160
deltamt=4.5
md=4.8*10**(-3)
deltamd=0.4*10**(-3)
ms=95*10**(-3)
deltams=5*10**(-3)
mb=4.18
deltamb=0.03
me=5.11*10**(-4)
deltame=5.11*10**(-6)
mmu=0.106
deltammu=0.106*10**(-2)
mtau=1.78
deltamtau=1.78*10**(-2)
Vus=0.225
deltaVus=0.225*10**(-2)
Vub=3.55*10**(-3)
deltaVub=0.15*10**(-3)
Vcb=4.14*10**(-2)
deltaVcb=1.2*10**(-3)

# %%
df=pd.read_csv("./SCANS/transitions_up_full.csv",index_col=[0])

plt.scatter(abs(df.h_low-df.h_high),df.theta)
plt.xlabel("$\\Delta h$",size=15)
plt.ylabel("$\\theta$",size=15)
plt.xticks(size=15)
plt.yticks(size=15)
plt.axhline(y=0,color="k",linestyle="--")
plt.show()

plt.scatter(abs(df.s_low-df.s_high),df.theta)
plt.xlabel("$\\Delta s$",size=15)
plt.ylabel("$\\theta$",size=15)
plt.xticks(size=15)
plt.yticks(size=15)
plt.axhline(y=0,color="k",linestyle="--")
plt.show()

# %%
df=pd.read_csv("./SCANS/transitions_up_full.csv",index_col=[0])

plt.scatter(df.theta,df.dT,c=df.charge)
plt.xlabel("$\\theta$",size=15)
plt.ylabel("$\\Delta T$",size=15)
plt.xticks(np.linspace(df.theta.min(),df.theta.max(),4),size=15)
plt.yticks(size=15)
plt.show()

plt.scatter(abs(df.ms-mh),df.dT)
plt.xlabel("$ |m_s - m_h|$",size=15)
plt.ylabel("$\\Delta T$",size=15)
plt.xticks(size=15)
plt.yticks(size=15)
plt.show()


plt.scatter(df.dPhi,df.dT)
plt.xlabel("$\\Delta \\phi$",size=15)
plt.ylabel("$\\Delta T$",size=15)
plt.xticks(size=15)
plt.yticks(size=15)
plt.show()

# %%
df=pd.read_csv("./SCANS/transitions_up_full.csv",index_col=[0])
plt.scatter(df.alpha,df.beta,c=df.charge)
plt.xlabel("$\\alpha$",size=15)
plt.ylabel("$\\beta/H$",size=15)
plt.xticks(size=15)
plt.yticks(size=15)
plt.show()

# %%
df=pd.read_csv("./SCANS/transitions_up_full.csv",index_col=[0])

plt.scatter(df[df.charge==1].alpha,df[df.charge==1].beta,label="set 1")
plt.scatter(df[df.charge==2].alpha,df[df.charge==2].beta,label="set 2")
plt.scatter(df[df.charge==3].alpha,df[df.charge==3].beta,label="set 3")

plt.xlabel("$\\alpha$",size=15)
plt.ylabel("$\\beta/H$",size=15)
plt.xticks(size=15)
plt.yticks(size=15)
plt.legend()
plt.tight_layout()
plt.savefig("./SCANS/my_fig.png")
plt.show()
